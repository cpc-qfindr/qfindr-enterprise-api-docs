# %% [markdown]
# # はじめに

# %% [markdown]
# 企業情報リサーチツールQFINDRのエンタープライズ向けAPI（QFINDR API）のご利用方法の一例をご紹介いたします。

# %% [markdown]
# QFINDR API はOpenAPI 3.0形式に対応した仕様を公開しています。
# 詳細な仕様に関しては APIドキュメント をご確認ください。

# %% [markdown]
# # OpenAPI Generator を用いたclientコードの生成

# %% [markdown]
# ## OpenAPI Generator

# %% [markdown]
# [OpenAPI Generator](https://openapi-generator.tech/) を用いて、APIに接続するコードを生成する形で、接続までの環境構築を行います。
# OpenAPI Generatorはいくつか実行方法がありますが、Colab環境ではPyPIからのCLIツールを導入して実行します。
# その他の実行方法に関しては、OpenAPI Genratorのドキュメントをご覧ください。
# https://openapi-generator.tech/docs/installation

# %% [markdown]
# > ご自身の手元で行われる場合はdocker環境での実行をお勧めします

# %% [markdown]
# ## QFINDR APIのスペックファイル

# %% [markdown]
# 作業フォルダを作成後、QFINDR APIのスペックファイルをダウンロードし、**`qfindr.json`** として配置します。
#
# スペックファイルはQFINDR APIドキュメンとのページよりダウンロード頂けます。
# https://qfindr.jp/docs/api/v1

# %% [markdown]
# ![API DOCS](https://github.com//cpc-qfindr/qfindr-enterprise-api-docs/blob/master/assets/api_docs_image.png)

# %% [markdown]
# ![How to add yaml](https://github.com//cpc-qfindr/qfindr-enterprise-api-docs/blob/master/assets/howto_colab_add_yaml.gif)

# %%
# !ls -la
# Out:
# total 156
# drwxr-xr-x 1 root root   4096 Jan 22 06:03 .
# drwxr-xr-x 1 root root   4096 Jan 22 06:01 ..
# drwxr-xr-x 4 root root   4096 Jan 16 14:24 .config
# drwxr-xr-x 7 root root   4096 Jan 22 06:03 qfindr_api
# -rw-r--r-- 1 root root 136325 Jan 22 06:01 qfindr.json
# drwxr-xr-x 1 root root   4096 Jan 16 14:24 sample_data

# %% [markdown]
# ## openapi-generator-cliのインストール

# %% [markdown]
# pipにて `openapi-generator-cli` をインストールします。
# `openapi-generator-cli` の実行には Java 環境が必要です。
# Javaバイナリの代わりにjdk4pyでインストールすることもできます。(python>=3.10が必要です)

# %%
pip install openapi-generator-cli[jdk4py]
# Out:
# Requirement already satisfied: openapi-generator-cli[jdk4py] in /usr/local/lib/python3.12/dist-packages (7.19.0)
# Requirement already satisfied: jdk4py<22,>=21.0.4.1 in /usr/local/lib/python3.12/dist-packages (from openapi-generator-cli[jdk4py]) (21.0.8.0)

# %% [markdown]
# ## clientコードの生成

# %% [markdown]
# openapi clientコードを生成します。
# QFINDR APIのスペックファイル `qfindr.json` を指定し、`./qfindr_api` に python のコードを生成します。

# %%
# !openapi-generator-cli generate \
  -i ./qfindr.json \
  -o ./qfindr_api \
  -g python
# Out:
# [main] INFO  o.o.codegen.DefaultGenerator - Generating with dryRun=false
# [main] INFO  o.o.codegen.DefaultGenerator - OpenAPI Generator: python (client)
# [main] INFO  o.o.codegen.DefaultGenerator - Generator 'python' is considered stable.
# [main] INFO  o.o.c.l.AbstractPythonCodegen - Environment variable PYTHON_POST_PROCESS_FILE not defined so the Python code may not be properly formatted. To define it, try 'export PYTHON_POST_PROCESS_FILE="/usr/local/bin/yapf -i"' (Linux/Mac)
# [main] INFO  o.o.c.l.AbstractPythonCodegen - NOTE: To enable file post-processing, 'enablePostProcessFile' must be set to `true` (--enable-post-process-file for CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as companies_search_200_response. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings companies_search_200_response=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings companies_search_200_response=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as companies_search_count_200_response. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings companies_search_count_200_response=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings companies_search_count_200_response=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as banks_search_request. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings banks_search_request=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings banks_search_request=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as banks_branches_search_request. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings banks_branches_search_request=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings banks_branches_search_request=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as usage_200_response_companies_search. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings usage_200_response_companies_search=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings usage_200_response_companies_search=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as usage_200_response. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings usage_200_response=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings usage_200_response=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as token_200_response. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings token_200_response=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings token_200_response=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_sectors_inner. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_sectors_inner=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_sectors_inner=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_areas_inner. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_areas_inner=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_areas_inner=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_operating_profit_changes. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_operating_profit_changes=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_operating_profit_changes=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_current_profit_changes. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_current_profit_changes=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_current_profit_changes=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_debt_changes. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_debt_changes=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_debt_changes=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_sales_sales. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_sales_sales=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_sales_sales=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_sales_lag1. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_sales_lag1=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_sales_lag1=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_sales_lag2. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_sales_lag2=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_sales_lag2=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_sales. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_sales=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_sales=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_operating_income_operating_income. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_operating_income_operating_income=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_operating_income_operating_income=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_operating_income_lag1. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_operating_income_lag1=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_operating_income_lag1=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_operating_income_lag2. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_operating_income_lag2=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_operating_income_lag2=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_operating_income. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_operating_income=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_operating_income=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_ordinary_profit_ordinary_profit. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_ordinary_profit_ordinary_profit=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_ordinary_profit_ordinary_profit=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_ordinary_profit_lag1. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_ordinary_profit_lag1=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_ordinary_profit_lag1=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_ordinary_profit_lag2. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_ordinary_profit_lag2=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_ordinary_profit_lag2=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_ordinary_profit. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_ordinary_profit=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_ordinary_profit=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_current_income_current_income. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_current_income_current_income=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_current_income_current_income=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_current_income_lag1. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_current_income_lag1=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_current_income_lag1=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_current_income_lag2. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_current_income_lag2=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_current_income_lag2=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_current_income. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_current_income=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_current_income=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_ebitda_ebitda. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_ebitda_ebitda=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_ebitda_ebitda=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_ebitda_lag1. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_ebitda_lag1=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_ebitda_lag1=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_ebitda_lag2. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_ebitda_lag2=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_ebitda_lag2=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_ebitda. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_ebitda=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_ebitda=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_total_debt_total_debt. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_total_debt_total_debt=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_total_debt_total_debt=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_total_debt_lag1. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_total_debt_lag1=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_total_debt_lag1=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_total_debt_lag2. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_total_debt_lag2=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_total_debt_lag2=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_total_debt. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_total_debt=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_total_debt=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_shareholders_equity_shareholders_equity. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_shareholders_equity_shareholders_equity=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_shareholders_equity_shareholders_equity=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_shareholders_equity_lag1. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_shareholders_equity_lag1=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_shareholders_equity_lag1=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_shareholders_equity_lag2. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_shareholders_equity_lag2=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_shareholders_equity_lag2=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1_shareholders_equity. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1_shareholders_equity=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1_shareholders_equity=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance1. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance1=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance1=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance2_liquidity. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance2_liquidity=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance2_liquidity=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance2_increse_of_sales. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance2_increse_of_sales=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance2_increse_of_sales=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance2_operating_income_on_sales. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance2_operating_income_on_sales=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance2_operating_income_on_sales=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance2_capital_asset_ratio. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance2_capital_asset_ratio=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance2_capital_asset_ratio=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance2_actual_interest_rate. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance2_actual_interest_rate=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance2_actual_interest_rate=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance2_principal_repayment_power. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance2_principal_repayment_power=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance2_principal_repayment_power=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance2_interest_repayment_power. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance2_interest_repayment_power=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance2_interest_repayment_power=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance2_debt_sales_ratio. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance2_debt_sales_ratio=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance2_debt_sales_ratio=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance2_debt_ebitda_ratio. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance2_debt_ebitda_ratio=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance2_debt_ebitda_ratio=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance2_depreciation_sales_ratio. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance2_depreciation_sales_ratio=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance2_depreciation_sales_ratio=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance2_fixed_long_term_conformance_ratio. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance2_fixed_long_term_conformance_ratio=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance2_fixed_long_term_conformance_ratio=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance2_fixed_ratio. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance2_fixed_ratio=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance2_fixed_ratio=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance2_land_turnover. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance2_land_turnover=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance2_land_turnover=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance2. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance2=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance2=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance3_continuous. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance3_continuous=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance3_continuous=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance3_rank_sales_rank. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance3_rank_sales_rank=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance3_rank_sales_rank=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance3_rank_sales_growth_rank. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance3_rank_sales_growth_rank=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance3_rank_sales_growth_rank=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance3_rank_operating_margin_rank. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance3_rank_operating_margin_rank=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance3_rank_operating_margin_rank=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance3_rank_total_capital_turnover_rank. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance3_rank_total_capital_turnover_rank=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance3_rank_total_capital_turnover_rank=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance3_rank_accounts_receivable_turnover_rank. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance3_rank_accounts_receivable_turnover_rank=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance3_rank_accounts_receivable_turnover_rank=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance3_rank_accounts_payable_turnover_rank. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance3_rank_accounts_payable_turnover_rank=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance3_rank_accounts_payable_turnover_rank=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance3_rank_equity_ratio_rank. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance3_rank_equity_ratio_rank=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance3_rank_equity_ratio_rank=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance3_rank_sales_interest_coverage_ratio_rank. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance3_rank_sales_interest_coverage_ratio_rank=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance3_rank_sales_interest_coverage_ratio_rank=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance3_rank. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance3_rank=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance3_rank=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_finance3. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_finance3=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_finance3=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_score_rank_by_sector. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_score_rank_by_sector=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_score_rank_by_sector=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_score_rank_by_sector_change_width. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_score_rank_by_sector_change_width=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_score_rank_by_sector_change_width=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_score_rating_code. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_score_rating_code=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_score_rating_code=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_score_fin_rank. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_score_fin_rank=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_score_fin_rank=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_score_fin_rank_changes. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_score_fin_rank_changes=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_score_fin_rank_changes=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_score_est_mcap. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_score_est_mcap=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_score_est_mcap=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_score. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_score=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_score=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_relates_banks_inner. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_relates_banks_inner=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_relates_banks_inner=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_relates_stockholder_percent. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_relates_stockholder_percent=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_relates_stockholder_percent=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_relates_delta_stockholder_percent. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_relates_delta_stockholder_percent=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_relates_delta_stockholder_percent=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_relates. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_relates=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_relates=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_president_age_president. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_president_age_president=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_president_age_president=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_president. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_president=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_president=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_ambition_rank. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_ambition_rank=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_ambition_rank=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_ambition_belong_cluster_rank_growth. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_ambition_belong_cluster_rank_growth=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_ambition_belong_cluster_rank_growth=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_ambition_belong_cluster_rank_sales. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_ambition_belong_cluster_rank_sales=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_ambition_belong_cluster_rank_sales=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_ambition_belong_cluster_rank_profit_margin. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_ambition_belong_cluster_rank_profit_margin=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_ambition_belong_cluster_rank_profit_margin=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_ambition_belong_cluster_rank_stock_return. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_ambition_belong_cluster_rank_stock_return=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_ambition_belong_cluster_rank_stock_return=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_ambition_belong_cluster_rank. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_ambition_belong_cluster_rank=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_ambition_belong_cluster_rank=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_ambition_prospect_cluster_rank. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_ambition_prospect_cluster_rank=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_ambition_prospect_cluster_rank=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_ambition. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_ambition=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_ambition=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_other_assignment. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_other_assignment=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_other_assignment=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_other_stage. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_other_stage=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_other_stage=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_other_nenkin_num_members. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_other_nenkin_num_members=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_other_nenkin_num_members=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_other_acc_month. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_other_acc_month=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_other_acc_month=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_other_capital_stock. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_other_capital_stock=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_other_capital_stock=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_other_financial_transaction_needs. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_other_financial_transaction_needs=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_other_financial_transaction_needs=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_other_excludes. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_other_excludes=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_other_excludes=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_other. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_other=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_other=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_word. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_word=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_word=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as CompanySearch_sort. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings CompanySearch_sort=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings CompanySearch_sort=NewModel,ModelA=NewModelA in CLI).
# [main] WARN  o.o.codegen.utils.ModelUtils - Failed to get the schema name: null
# [main] ERROR o.o.codegen.utils.ModelUtils - Failed to obtain schema from code
# [main] ERROR o.o.codegen.utils.ModelUtils - Failed to obtain schema from code
# [main] ERROR o.o.codegen.utils.ModelUtils - Failed to obtain schema from code
# [main] ERROR o.o.codegen.utils.ModelUtils - Failed to obtain schema from code
# [main] ERROR o.o.codegen.utils.ModelUtils - Failed to obtain schema from code
# [main] ERROR o.o.codegen.utils.ModelUtils - Failed to obtain schema from code
# [main] ERROR o.o.codegen.utils.ModelUtils - Failed to obtain schema from code
# [main] ERROR o.o.codegen.utils.ModelUtils - Failed to obtain schema from code
# [main] ERROR o.o.codegen.utils.ModelUtils - Failed to obtain schema from code
# [main] ERROR o.o.codegen.utils.ModelUtils - Failed to obtain schema from code
# [main] ERROR o.o.codegen.utils.ModelUtils - Failed to obtain schema from code
# [main] ERROR o.o.codegen.utils.ModelUtils - Failed to obtain schema from code
# [main] ERROR o.o.codegen.utils.ModelUtils - Failed to obtain schema from code
# [main] ERROR o.o.codegen.utils.ModelUtils - Failed to obtain schema from code
# [main] ERROR o.o.codegen.utils.ModelUtils - Failed to obtain schema from code
# [main] ERROR o.o.codegen.utils.ModelUtils - Failed to obtain schema from code
# [main] WARN  o.o.codegen.utils.ModelUtils - Failed to get the schema name: null
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/bank.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_bank.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/Bank.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/bank_branch.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_bank_branch.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/BankBranch.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/banks_branches_search_request.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_banks_branches_search_request.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/BanksBranchesSearchRequest.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/banks_search_request.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_banks_search_request.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/BanksSearchRequest.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/city.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_city.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/City.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/companies_search200_response.py
# ...
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/CompanySearchOtherFinancialTransactionNeeds.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/company_search_other_nenkin_num_members.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_company_search_other_nenkin_num_members.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/CompanySearchOtherNenkinNumMembers.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/company_search_other_stage.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_company_search_other_stage.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/CompanySearchOtherStage.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/company_search_president.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_company_search_president.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/CompanySearchPresident.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/company_search_president_age_president.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_company_search_president_age_president.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/CompanySearchPresidentAgePresident.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/company_search_relates.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_company_search_relates.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/CompanySearchRelates.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/company_search_relates_banks_inner.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_company_search_relates_banks_inner.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/CompanySearchRelatesBanksInner.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/company_search_relates_delta_stockholder_percent.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_company_search_relates_delta_stockholder_percent.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/CompanySearchRelatesDeltaStockholderPercent.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/company_search_relates_stockholder_percent.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_company_search_relates_stockholder_percent.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/CompanySearchRelatesStockholderPercent.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/company_search_result.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_company_search_result.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/CompanySearchResult.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/company_search_score.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_company_search_score.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/CompanySearchScore.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/company_search_score_est_mcap.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_company_search_score_est_mcap.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/CompanySearchScoreEstMcap.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/company_search_score_fin_rank.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_company_search_score_fin_rank.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/CompanySearchScoreFinRank.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/company_search_score_fin_rank_changes.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_company_search_score_fin_rank_changes.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/CompanySearchScoreFinRankChanges.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/company_search_score_rank_by_sector.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_company_search_score_rank_by_sector.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/CompanySearchScoreRankBySector.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/company_search_score_rank_by_sector_change_width.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_company_search_score_rank_by_sector_change_width.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/CompanySearchScoreRankBySectorChangeWidth.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/company_search_score_rating_code.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_company_search_score_rating_code.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/CompanySearchScoreRatingCode.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/company_search_sectors_inner.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_company_search_sectors_inner.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/CompanySearchSectorsInner.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/company_search_sort.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_company_search_sort.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/CompanySearchSort.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/company_search_word.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_company_search_word.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/CompanySearchWord.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/error.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_error.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/Error.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/fin_rank.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_fin_rank.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/FinRank.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/legal_kind.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_legal_kind.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/LegalKind.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/prefecture.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_prefecture.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/Prefecture.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/rating.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_rating.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/Rating.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/region.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_region.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/Region.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/sector.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_sector.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/Sector.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/sector_has_children.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_sector_has_children.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/SectorHasChildren.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/token200_response.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_token200_response.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/Token200Response.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/usage200_response.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_usage200_response.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/Usage200Response.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/usage200_response_companies_search.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_usage200_response_companies_search.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/Usage200ResponseCompaniesSearch.md
# [main] WARN  o.o.codegen.utils.ModelUtils - Failed to get the schema name: null
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/api/default_api.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/test/test_default_api.py (Test files never overwrite an existing file of the same name.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/docs/DefaultApi.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/README.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/tox.ini
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/test-requirements.txt
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/requirements.txt
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/setup.cfg
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/git_push.sh
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/.gitignore
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/.travis.yml
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/.github/workflows/python.yml
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/.gitlab-ci.yml
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/setup.py
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/pyproject.toml
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/py.typed
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/configuration.py
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/__init__.py
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/models/__init__.py
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/api/__init__.py
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/exceptions.py
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/test/__init__.py
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/api_client.py
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/api_response.py
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/openapi_client/rest.py
# [main] INFO  o.o.codegen.TemplateManager - Skipped /content/./qfindr_api/.openapi-generator-ignore (Skipped by supportingFiles options supplied by user.)
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/.openapi-generator/VERSION
# [main] INFO  o.o.codegen.TemplateManager - writing file /content/./qfindr_api/.openapi-generator/FILES
# ############################################################################################
# # Thanks for using OpenAPI Generator.                                                      #
# # We appreciate your support! Please consider donation to help us maintain this project.   #
# # https://opencollective.com/openapi_generator/donate                                      #
# ############################################################################################

# %%
# !ls -la ./qfindr_api
# Out:
# total 104
# drwxr-xr-x 7 root root  4096 Jan 22 06:03 .
# drwxr-xr-x 1 root root  4096 Jan 22 06:03 ..
# drwxr-xr-x 2 root root 12288 Jan 22 06:03 docs
# drwxr-xr-x 3 root root  4096 Jan 22 06:03 .github
# -rw-r--r-- 1 root root   808 Jan 22 06:35 .gitignore
# -rw-r--r-- 1 root root   713 Jan 22 06:35 .gitlab-ci.yml
# -rw-r--r-- 1 root root  1830 Jan 22 06:35 git_push.sh
# drwxr-xr-x 5 root root  4096 Jan 22 06:03 openapi_client
# drwxr-xr-x 2 root root  4096 Jan 22 06:03 .openapi-generator
# -rw-r--r-- 1 root root  1040 Jan 22 06:03 .openapi-generator-ignore
# -rw-r--r-- 1 root root  2480 Jan 22 06:35 pyproject.toml
# -rw-r--r-- 1 root root 13460 Jan 22 06:35 README.md
# -rw-r--r-- 1 root root    92 Jan 22 06:35 requirements.txt
# -rw-r--r-- 1 root root    28 Jan 22 06:35 setup.cfg
# -rw-r--r-- 1 root root  1384 Jan 22 06:35 setup.py
# drwxr-xr-x 2 root root 12288 Jan 22 06:03 test
# -rw-r--r-- 1 root root   112 Jan 22 06:35 test-requirements.txt
# -rw-r--r-- 1 root root   150 Jan 22 06:35 tox.ini
# -rw-r--r-- 1 root root   431 Jan 22 06:35 .travis.yml

# %% [markdown]
# # 生成コードの利用

# %% [markdown]
# 生成したクライアントコードのディレクトリに移動し、依存ライブラリをインストールします。

# %%
# !cd qfindr_api && pip install -r requirements.txt
# Out:
# Requirement already satisfied: urllib3<3.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: python_dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.12.3)
# Requirement already satisfied: typing-extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python_dateutil>=2.8.2->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2->-r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2->-r requirements.txt (line 3)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2->-r requirements.txt (line 3)) (0.4.2)

# %% [markdown]
# 生成したコードを用いて、APIリクエストを行います。
# 生成物一式をライブラリーとしてインストールするか、コードを改変して利用します。

# %% [markdown]
# colab環境では生成コードを利用して、APIをコールするサンプルを示します。

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# `./qfindr_api`に移動

# %%
cd ./qfindr_api
# Out:
# /content/qfindr_api

# %%
pwd
# Out:
# '/content/qfindr_api'

# %% [markdown]
# ## APIクライアントの初期化

# %% [markdown]
# colab環境では左メニューの「シークレット」よりAPIキーを登録します。
#
# 名前 : `QFINDR_API_KEY`
# 値 : { 発行済みのAPIトークン }
# 　　※qfindrサービスにログイン後、アカウントページよりご確認いただけます。
#
# colab環境外では、環境変数から取得するなど、実行環境に合わせて調整してください。

# %% [markdown]
# ![How to add secret](https://github.com//cpc-qfindr/qfindr-enterprise-api-docs/blob/master/assets/assets/howto_colab_add_secret.gif)

# %%
import os

import openapi_client as openapi_client

configuration = openapi_client.Configuration(
    host = "https://qfindr.jp/api/v1"
)

# Bare認証用のアクセストークンを指定します
# configuration.access_token = os.environ.get("QFINDR_API_KEY")
#
# colab環境ではシークレットから取得します
from google.colab import userdata
configuration.access_token = userdata.get('QFINDR_API_KEY')

# APIクライアントを初期化
api_client = openapi_client.ApiClient(configuration)

# クライアントインスタンスを生成
api_instance = openapi_client.DefaultApi(api_client)

# %% [markdown]
# ## API利用例

# %% [markdown]
# ### 例）銀行検索API

# %% [markdown]
# 銀行検索APIをコールして銀行名での部分一致の結果を取得

# %%
try:
    api_response = api_instance.banks_search(openapi_client.BanksSearchRequest(bank_name="みずほ"))
    print("The response of DefaultApi->banks_search:\n")

    import pprint
    pprint.pprint(api_response)
    if len(api_response) > 0 :
        bank = api_response[0]
        pprint.pprint(bank)
except openapi_client.ApiException as e:
    print("Exception when calling DefaultApi->banks_search: %s\n" % e)
# Out:
# The response of DefaultApi->banks_search:
#
# [Bank(name='みずほ銀行'), Bank(name='みずほ信託銀行'), Bank(name='埼玉みずほ農協')]
# Bank(name='みずほ銀行')

# %% [markdown]
# ### 例）銀行支店検索API

# %% [markdown]
# 銀行検索結果を用いて、支店情報を取得

# %%
try:
    # 銀行名から検索する
    banks_branches_search_request = openapi_client.BanksBranchesSearchRequest(bank_name=bank.name)

    api_response = api_instance.banks_branches_search(banks_branches_search_request)
    print("The response of DefaultApi->banks_branches_search:\n")

    import pprint
    pprint.pprint(api_response[0])
    pprint.pprint(api_response[1])
    print("... and more. total %s BankBranchs" % len(api_response))
except openapi_client.ApiException as e:
    print("Exception when calling DefaultApi->banks_branches_search: %s\n" % e)
# Out:
# The response of DefaultApi->banks_branches_search:
#
# BankBranch(bank_name='みずほ銀行', name='本店')
# BankBranch(bank_name='みずほ銀行', name='新橋')
# ... and more. total 463 BankBranchs

# %% [markdown]
# ### 例）企業検索API

# %% [markdown]
# 企業検索APIにて証券コード `7102` を検索

# %%
try:
    # 企業検索条件を設定
    company_search_request = openapi_client.CompanySearch(
        # フリーワードで証券コードを検索する
        word=openapi_client.CompanySearchWord(input="7203")
    )

    api_response = api_instance.companies_search(company_search_request)
    print("The response of DefaultApi->companies_search:\n")

    import pprint
    pprint.pprint(api_response.to_dict())

except openapi_client.ApiException as e:
    print("Exception when calling DefaultApi->companies_search: %s\n" % e)

# %% [markdown]
# ### 例）API利用状況の取得

# %%
try:

    api_response = api_instance.usage()
    print("The response of DefaultApi->usage:\n")

    import pprint
    pprint.pprint(api_response.to_dict())

except openapi_client.ApiException as e:
    print("Exception when calling DefaultApi->usage: %s\n" % e)
# Out:
# The response of DefaultApi->usage:
#
# {'companies/search': {'downloaded': 1, 'limit': 100000, 'result_limit': 3000},
#  'year_month': 202601}

# %% [markdown]
# ## 実際の使用シーンを想定した例

# %% [markdown]
# ### 法人番号を元に企業情報を取得
#
# **想定する用途**
# ・自社のデータベースとの連携するため、法人番号を元にQFINDR APIを使用する。
# ・APIレスポンスのうち、必要な項目の値と項目名を取得する。

# %%
from openapi_client.models.company_search_result import CompanySearchResult

def get_company_by_corporate_number(corporate_number) -> CompanySearchResult | None:
  try:
      # 企業検索条件を設定 (法人番号で検索)
      company_search_request = openapi_client.CompanySearch(
          word=openapi_client.CompanySearchWord(input=corporate_number) # Replace with the desired corporate number
      )

      api_response = api_instance.companies_search(company_search_request)

      if len(api_response.data) > 0:
        return api_response.data[0]

  except openapi_client.ApiException as e:
      print("Exception when calling DefaultApi->companies_search: %s\n" % e)

  return None

company = get_company_by_corporate_number("1180301018771")
if company:
  use_keys = [
      "corporate_number",
      "operating_income_on_sales", # 営業利益率
      "increse_of_sales" # 売上伸び率
      # ...
  ]
  data = { key: { "label": CompanySearchResult.model_fields[key].description, "value": getattr(company, key) } for key in use_keys }
  # import json
  # json.dumps(data)
  import pprint
  pprint.pprint(data)

# %% [markdown]
# ### 検索条件を出力件数上限以下に抑え、分割して全件取得を行う
# ・ある検索条件での検索結果件数を取得し、出力件数上限以上の場合は**地域別**に分割して取得する
# ・当月API利用状況を確認しながら行う

# %%
from typing import *

def exec_api(func):
    def wrapper(*args, **kwargs):
        print('--start api request --')
        try:
            return func(*args, **kwargs)
        except openapi_client.ApiException as e:
            print("Exception when calling api: %s\n" % e)
        return None
    return wrapper

@exec_api
def exec_api_usage() -> openapi_client.Usage200Response | None:
  api_response = api_instance.usage()
  return api_response

@exec_api
def exec_api_companies_search_count(request:openapi_client.CompanySearch) -> int | None:
  api_response = api_instance.companies_search_count(request)
  return api_response.total

@exec_api
def exec_api_companies_search(request:openapi_client.CompanySearch) -> List[openapi_client.CompanySearchResult] | None:
  total = exec_api_companies_search_count(request)
  api_usage = exec_api_usage()
  if total > 0 and check_companies_search_api_usage(api_usage):
    pass
  api_response = api_instance.companies_search(request)
  return api_response.data

def check_companies_search_api_usage(api_usage=None)-> bool:
  if api_usage is None:
    api_usage = exec_api_usage()

  if api_usage is None or api_usage.companies_search is None:
    return False

  import pprint
  pprint.pprint(api_usage.companies_search)
  # api_usage.companies_search.limit = -1: 無制限
  return api_usage.companies_search.limit < 0 or (api_usage.companies_search.downloaded < api_usage.companies_search.limit)

# 企業検索条件
# 例) 「太陽光発電」を企業概要に含む会社
company_search_request = openapi_client.CompanySearch(
    word=openapi_client.CompanySearchWord(input="太陽光発電",search_type="only_summary") # Replace with the desired corporate number
)
check_companies_search_api_usage()
# Out:
# --start api request --
# Usage200ResponseCompaniesSearch(limit=100000, result_limit=3000, downloaded=1, download_codes=None)
# True
